# %%
##Sheing Jing NG DECISION TREE 10/13/2016
##Objective: Perform machine learning experiments, supervised learning and implementation of 
##           decision tree algorithm on German Credit Data sets.
##Goals: To get a good prediction on "Creditability" after implementing decision tree training.

import pandas
import random
import math
from sklearn import cross_validation
from collections import Counter

#the class with functions to be used as entry points when
#either training (fit) or predicting (predict) with the
#decision tree algorithm
class DTree:
    def fit(self,predictor_columns_data,target_column_data):
        self.__root_node = DNode(predictor_columns_data,target_column_data)
        self.__root_node.train()
        
    def predict(self,df_of_new_examples):
        #apply the predict function to the whole series, one at a time, this returns the series with the return vals
        predictions = df_of_new_examples.apply(self.__root_node.predict,axis=1)
        return predictions
        
    def print_tree(self):
        self.__root_node.print_node()
        

#A class for representing non-leaf nodes in the decision tree
class DNode:
    
    #when we create this node, we pass it training examples to be used at this point
    #the predictor columns of these training examples is in predictor_columns_data
    #the corresponding target values to those predictor columns are in target_column_data
    def __init__(self,predictor_columns_data,target_column_data):
        
        self.__attribute = ''  #the attribute used to sort examples at this node
        self.__predictor_columns = predictor_columns_data #the training examples that have been sorted to this node
        self.__target_column = target_column_data #the corresponding target values for the training examples
        self.__child_nodes = {} #dictionary of the child nodes of this node, indexed by the value they have for self.__attribute
        self.__most_common_value_here = '' #for keeping track of which target value is most common among the examples at this node. This is used to make a decision when there's no appropriate child node to follow
        
    #this should use the training data to determine the best attribute to use
    #as is, it just chooses one at random, but you will fix it to use information gain
    def choose_attribute(self):
        self.__attribute = random.choice(self.__predictor_columns.columns.values) #what a terrible way to choose the attribute!
        
               
    def train(self):
        self.choose_attribute() #'best' attribute at this node
        
        #in case we need to make a decision here because we don't have any children with a particular attribute value    
        self.__most_common_value_here = self.__target_column.value_counts().idxmax()
        
        #gets all the values that these examples have in our chosen column
        attribute_values_here = self.__predictor_columns[self.__attribute].unique()

        #going through all possible values this attribute can have
        #and creating the appropriate child node
        for value in attribute_values_here: 
             
            #the subset of examples with the given value
            examples_for_child_predictor_cols = self.__predictor_columns[self.__predictor_columns[self.__attribute] == value] 
            examples_for_child_target_col = self.__target_column[self.__predictor_columns[self.__attribute] == value] #target values corresponding to the subset of examples with the given value
            
            #we grabbed the values from the examples themselves, so there should
            #be at least one example that has each value, but just in case there isn't
            #I don't want to crash the program
            if examples_for_child_target_col.empty:
                print("error: we shouldn't get here")
                
            #there are no columns left to use for decisions at the child
            #so lets make a leage node based on the most common target value in those examples
            elif len(examples_for_child_predictor_cols.columns.values) == 1:  
                #create a child with the most common target value here
                leaf_child = DLeaf( self.__most_common_value_here )
                self.__child_nodes[value] = leaf_child
                
            #if all child examples have the same target value, we make a leaf node
            elif len(examples_for_child_target_col.unique()) == 1: #all child examples have same class
                leaf_child = DLeaf( examples_for_child_target_col.unique()[0] ) #make leaf with that class
                self.__child_nodes[value] = leaf_child #put the leaf in the dictionary of children nodes
                
            else: #we have a regular decision node for this attribute value
                #get rid of the column for this attribute so it can't be selected again
                examples_for_child_predictor_cols = examples_for_child_predictor_cols.drop(self.__attribute,1) 
                
                new_child = DNode(examples_for_child_predictor_cols,examples_for_child_target_col)
                new_child.train() #generate the rest of the subtree for this child
                self.__child_nodes[value] = new_child #put the new child node in the dictionary of children nodes
            

    #print out the tree - not the prettiest, but you can see it.
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end=''), #print with no newline
        print(self.__attribute)
        for attr in self.__child_nodes.keys():
            for i in range(num_indents): 
                print("|", end='')
            print(":"+attr)
            self.__child_nodes[attr].print_node(num_indents+1)
            
    #make a prediction for a single new example
    #this only makes sense to call after the tree has been build (with train())
    def predict(self,new_example):
        #look up the right branch in our dictionary of children
        if new_example[self.__attribute] in self.__child_nodes:
            node_on_corresponding_branch = self.__child_nodes[new_example[self.__attribute]]
            return node_on_corresponding_branch.predict(new_example) #recursively call predict on the child node
        else:
            return self.__most_common_value_here #there was no child, so we predict the most common class of the examples at this node
        
#class for representing a leaf node in the tree
class DLeaf:
    
    #when we create the node, all we need to know is what we're going to predict if we get here
    def __init__(self,val_in_target_col):
        self.__target_value = val_in_target_col
    
    #just returns the prediction for a new example, 
    #this was probably called from predict() of a regular node one level up in the tree
    def predict(self,new_example):
        return self.__target_value
    
    #for displaying the tree
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end='')
        print("LEAF:",self.__target_value)
        
    
#simply compares two Pandas series and returns the proportion that match
#this can be used to compute the accuracy of the prediction list against
#the actual target column
def accuracy(series1, series2):
    correct = 0.0
    for index, value in series1.iteritems():
        if value == series2.loc[index]:
            correct += 1
    return (correct/len(series1))
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
###Question1:
###(10 points) In class, an example was shown for how to use the decision tree, using only 3 columns for prediction. Update it to use all of the categorical columns. 
###Discuss what you did and record how well the algorithm performs in your write-up (be specific - what was the actual accuracy, not a vague opinion of how well you thought it did or "about" what the accuracy was).
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@


import math
credit_data= pandas.read_csv('german_credit.csv')

train_data, test_data = cross_validation.train_test_split(credit_data,test_size = 0.1)
    
attributes_to_use=['Status of existing checking account','Credit history',\
                   'Purpose','Savings account/bonds','Present employment since',\
                    'Personal status and sex','Other debtors / guarantors',\
                    'Property','Other installment plans','Housing',\
                    'Job','Telephone','foreign worker',\
                    ]
                    

my_tree = DTree() 
my_tree.fit(train_data[attributes_to_use],train_data['Creditability'])
my_tree.print_tree()
predictions = my_tree.predict(test_data[attributes_to_use])
print(accuracy(test_data['Creditability'],predictions))
# Out:
# Job
# :A174
#  Present employment since
# |:A72
#   Purpose
# ||:A40
#    Status of existing checking account
# |||:A11
#     LEAF: 2
# |||:A14
#     LEAF: 1
# |||:A12
#     LEAF: 2
# ||:A42
#    Telephone
# |||:A192
#     Property
# ||||:A122
#      LEAF: 1
# ||||:A124
#      LEAF: 2
# ||||:A123
#      LEAF: 1
# |||:A191
#     LEAF: 1
# ||:A41
#    Status of existing checking account
# |||:A14
#     LEAF: 1
# |||:A12
#     LEAF: 2
# ||:A43
#    Personal status and sex
# |||:A93
#     LEAF: 2
# |||:A94
#     LEAF: 1
# |||:A92
#     LEAF: 1
# |:A74
#   Telephone
# ||:A192
#    Status of existing checking account
# |||:A11
#     Personal status and sex
# ||||:A93
#      LEAF: 1
# ||||:A94
#      LEAF: 1
# ||||:A92
#      LEAF: 2
# |||:A14
#     LEAF: 1
# |||:A12
#     Housing
# ||||:A151
#      LEAF: 1
# ||||:A152
#      Personal status and sex
# |||||:A93
#       LEAF: 2
# |||||:A91
#       LEAF: 1
# |||||:A92
#       LEAF: 1
# ||:A191
#    LEAF: 1
# |:A75
#   Purpose
# ||:A40
#    Other debtors / guarantors
# |||:A101
#     Telephone
# ||||:A192
#      Status of existing checking account
# |||||:A11
#       Savings account/bonds
# ||||||:A61
#        Housing
# |||||||:A153
#         LEAF: 1
# |||||||:A152
#         LEAF: 2
# |||||:A14
#       foreign worker
# ||||||:A201
#        Personal status and sex
# |||||||:A93
#         Other installment plans
# ||||||||:A141
#          LEAF: 1
# ||||||||:A143
#          Property
# |||||||||:A122
#           LEAF: 1
# |||||||||:A124
#           LEAF: 2
# |||||||||:A123
#           LEAF: 1
# |||||||:A92
#         LEAF: 1
# |||||:A12
#       LEAF: 2
# ||||:A191
#      Savings account/bonds
# |||||:A61
#       Other installment plans
# ||||||:A143
#        LEAF: 1
# ||||||:A141
#        LEAF: 2
# ||:A410
#    Other debtors / guarantors
# |||:A101
#     Credit history
# ||||:A31
#      LEAF: 2
# ||||:A34
#      LEAF: 1
# ||:A49
#    Property
# |||:A121
#     Credit history
# ||||:A32
#      LEAF: 1
# ||||:A33
#      LEAF: 2
# |||:A124
#     LEAF: 2
# |||:A123
#     LEAF: 1
# ||:A46
#    Property
# |||:A124
#     LEAF: 2
# |||:A123
#     Telephone
# ||||:A192
#      Credit history
# |||||:A32
#       LEAF: 1
# |||||:A34
#       LEAF: 2
# ||:A42
#    Telephone
# |||:A192
#     Property
# ||||:A121
#      LEAF: 1
# ||||:A122
#      LEAF: 2
# ||||:A124
#      LEAF: 2
# ||:A41
#    Other debtors / guarantors
# |||:A101
#     Personal status and sex
# ||||:A93
#      LEAF: 1
# ||||:A92
#      Other installment plans
# |||||:A141
#       LEAF: 2
# |||||:A143
#       Property
# ||||||:A124
#        LEAF: 2
# ||||||:A123
#        LEAF: 1
# ||:A43
#    LEAF: 1
# |:A71
#   Property
# ||:A121
#    Personal status and sex
# |||:A92
#     LEAF: 2
# |||:A91
#     LEAF: 1
# ||:A122
#    foreign worker
# |||:A201
#     Telephone
# ||||:A192
#      Housing
# |||||:A151
#       LEAF: 1
# |||||:A152
#       Savings account/bonds
# ||||||:A61
#        LEAF: 1
# ||||||:A62
#        LEAF: 2
# ||||||:A65
#        LEAF: 1
# ||:A124
#    foreign worker
# |||:A201
#     Status of existing checking account
# ||||:A11
#      LEAF: 1
# ||||:A14
#      LEAF: 1
# ||||:A12
#      Other debtors / guarantors
# |||||:A102
#       LEAF: 1
# |||||:A101
#       Other installment plans
# ||||||:A141
#        LEAF: 1
# ||||||:A143
#        Purpose
# |||||||:A410
#         LEAF: 1
# |||||||:A41
#         LEAF: 2
# |||||||:A43
#         LEAF: 2
# ||:A123
#    Savings account/bonds
# |||:A61
#     Credit history
# ||||:A32
#      Purpose
# |||||:A49
#       LEAF: 2
# |||||:A42
#       LEAF: 2
# |||||:A410
#       LEAF: 1
# |||||:A43
#       LEAF: 2
# ||||:A34
#      Status of existing checking account
# |||||:A14
#       LEAF: 1
# |||||:A12
#       LEAF: 2
# |:A73
#   Telephone
# ||:A192
#    Purpose
# |||:A410
#     LEAF: 2
# |||:A49
#     Other installment plans
# ||||:A141
#      LEAF: 1
# ||||:A143
#      Other debtors / guarantors
# |||||:A103
#       LEAF: 1
# |||||:A101
#       Savings account/bonds
# ||||||:A61
#        LEAF: 1
# ||||||:A64
#        LEAF: 2
# ||||:A142
#      LEAF: 2
# |||:A42
#     LEAF: 2
# |||:A40
#     LEAF: 1
# |||:A41
#     LEAF: 1
# |||:A43
#     Credit history
# ||||:A32
#      LEAF: 1
# ||||:A33
#      LEAF: 2
# ||:A191
#    Credit history
# |||:A32
#     Other debtors / guarantors
# ||||:A101
#      Property
# |||||:A123
#       Purpose
# ||||||:A41
#        LEAF: 2
# ||||||:A43
#        LEAF: 1
# |||:A33
#     LEAF: 1
# :A171
#  Other debtors / guarantors
# |:A102
#   Housing
# ||:A151
#    LEAF: 2
# ||:A152
#    LEAF: 1
# |:A101
#   Status of existing checking account
# ||:A11
#    Other installment plans
# |||:A143
#     Telephone
# ||||:A192
#      LEAF: 1
# ||||:A191
#      LEAF: 2
# ||:A14
#    LEAF: 1
# ||:A13
#    Credit history
# |||:A31
#     LEAF: 2
# |||:A32
#     LEAF: 1
# |||:A34
#     LEAF: 1
# ||:A12
#    Housing
# |||:A151
#     Purpose
# ||||:A40
#      Property
# |||||:A121
#       Savings account/bonds
# ||||||:A61
#        LEAF: 2
# ||||||:A65
#        LEAF: 1
# ||||:A43
#      LEAF: 1
# |||:A153
#     LEAF: 1
# |||:A152
#     Savings account/bonds
# ||||:A61
#      LEAF: 1
# ||||:A65
#      Property
# |||||:A121
#       LEAF: 1
# |||||:A122
#       LEAF: 2
# |||||:A124
#       LEAF: 1
# :A173
#  Credit history
# |:A31
#   Housing
# ||:A151
#    Status of existing checking account
# |||:A11
#     Other installment plans
# ||||:A141
#      LEAF: 1
# ||||:A143
#      LEAF: 2
# |||:A14
#     LEAF: 1
# |||:A13
#     LEAF: 1
# |||:A12
#     LEAF: 2
# ||:A153
#    LEAF: 2
# ||:A152
#    Personal status and sex
# |||:A93
#     Purpose
# ||||:A40
#      LEAF: 2
# ||||:A42
#      Telephone
# |||||:A192
#       LEAF: 1
# |||||:A191
#       LEAF: 2
# ||||:A49
#      LEAF: 1
# |||:A92
#     LEAF: 1
# |||:A91
#     LEAF: 2
# |:A30
#   Purpose
# ||:A40
#    Property
# |||:A122
#     LEAF: 2
# |||:A124
#     LEAF: 1
# |||:A123
#     Other debtors / guarantors
# ||||:A101
#      Telephone
# |||||:A191
#       Status of existing checking account
# ||||||:A11
#        LEAF: 2
# ||||||:A12
#        Personal status and sex
# |||||||:A92
#         Present employment since
# ||||||||:A72
#          Other installment plans
# |||||||||:A143
#           foreign worker
# ||||||||||:A201
#            Housing
# |||||||||||:A152
#             Savings account/bonds
# ||||||||||||:A63
#              LEAF: 2
# ||||||||||||:A62
#              LEAF: 2
# ||:A45
#    LEAF: 1
# ||:A49
#    Other installment plans
# |||:A141
#     LEAF: 1
# |||:A143
#     Telephone
# ||||:A192
#      LEAF: 2
# ||||:A191
#      Property
# |||||:A123
#       Other debtors / guarantors
# ||||||:A101
#        Savings account/bonds
# |||||||:A61
#         Housing
# ||||||||:A151
#          LEAF: 2
# ||||||||:A152
#          LEAF: 1
# |||:A142
#     LEAF: 2
# ||:A42
#    Personal status and sex
# |||:A93
#     Other installment plans
# ||||:A143
#      Housing
# |||||:A153
#       LEAF: 2
# |||||:A152
#       LEAF: 1
# ||||:A141
#      LEAF: 2
# |||:A91
#     LEAF: 1
# |||:A92
#     Other installment plans
# ||||:A143
#      LEAF: 2
# ||||:A141
#      LEAF: 1
# ||:A41
#    foreign worker
# |||:A201
#     Personal status and sex
# ||||:A93
#      LEAF: 2
# ||||:A94
#      LEAF: 1
# ||:A43
#    LEAF: 2
# |:A32
#   Telephone
# ||:A192
#    Property
# |||:A121
#     Status of existing checking account
# ||||:A11
#      LEAF: 2
# ||||:A14
#      LEAF: 1
# ||||:A13
#      LEAF: 1
# ||||:A12
#      Other debtors / guarantors
# |||||:A103
#       LEAF: 1
# |||||:A101
#       Savings account/bonds
# ||||||:A61
#        LEAF: 1
# ||||||:A63
#        LEAF: 1
# ||||||:A64
#        LEAF: 1
# ||||||:A65
#        LEAF: 2
# |||:A122
#     Purpose
# ||||:A43
#      Other installment plans
# |||||:A143
#       Present employment since
# ||||||:A72
#        Savings account/bonds
# |||||||:A61
#         Status of existing checking account
# ||||||||:A14
#          LEAF: 1
# ||||||||:A12
#          LEAF: 2
# ||||||:A74
#        LEAF: 1
# ||||||:A75
#        LEAF: 1
# ||||||:A73
#        LEAF: 1
# |||||:A142
#       LEAF: 1
# ||||:A40
#      Other debtors / guarantors
# |||||:A103
#       LEAF: 1
# |||||:A101
#       Other installment plans
# ||||||:A143
#        Present employment since
# |||||||:A73
#         LEAF: 2
# |||||||:A74
#         LEAF: 1
# |||||||:A75
#         LEAF: 1
# ||||:A48
#      LEAF: 1
# ||||:A45
#      LEAF: 1
# ||||:A44
#      LEAF: 1
# ||||:A42
#      Present employment since
# |||||:A72
#       LEAF: 1
# |||||:A74
#       LEAF: 1
# |||||:A75
#       foreign worker
# ||||||:A201
#        Other debtors / guarantors
# |||||||:A101
#         Housing
# ||||||||:A151
#          LEAF: 1
# ||||||||:A152
#          Personal status and sex
# |||||||||:A93
#           LEAF: 1
# |||||||||:A92
#           Status of existing checking account
# ||||||||||:A11
#            LEAF: 1
# ||||||||||:A12
#            LEAF: 2
# ||||:A49
#      LEAF: 1
# ||||:A41
#      Housing
# |||||:A153
#       LEAF: 2
# |||||:A152
#       LEAF: 1
# ||||:A46
#      LEAF: 1
# |||:A124
#     Purpose
# ||||:A40
#      Other installment plans
# |||||:A143
#       Personal status and sex
# ||||||:A93
#        Savings account/bonds
# |||||||:A65
#         Status of existing checking account
# ||||||||:A14
#          LEAF: 1
# ||||||||:A12
#          LEAF: 2
# ||||||:A92
#        LEAF: 1
# ||||:A46
#      foreign worker
# |||||:A201
#       Status of existing checking account
# ||||||:A14
#        Other installment plans
# |||||||:A143
#         LEAF: 1
# |||||||:A142
#         LEAF: 2
# ||||||:A12
#        LEAF: 2
# ||||:A42
#      LEAF: 1
# ||||:A41
#      Status of existing checking account
# |||||:A11
#       Housing
# ||||||:A153
#        Savings account/bonds
# |||||||:A61
#         LEAF: 2
# |||||||:A65
#         LEAF: 1
# ||||||:A152
#        LEAF: 1
# |||||:A14
#       LEAF: 1
# |||||:A12
#       LEAF: 1
# ||||:A43
#      Present employment since
# |||||:A73
#       LEAF: 1
# |||||:A74
#       LEAF: 2
# |||||:A75
#       LEAF: 1
# |||:A123
#     Status of existing checking account
# ||||:A11
#      LEAF: 2
# ||||:A14
#      Personal status and sex
# |||||:A93
#       Purpose
# ||||||:A49
#        LEAF: 1
# ||||||:A40
#        LEAF: 1
# ||||||:A42
#        LEAF: 1
# ||||||:A41
#        LEAF: 1
# ||||||:A43
#        foreign worker
# |||||||:A201
#         Housing
# ||||||||:A152
#          Savings account/bonds
# |||||||||:A63
#           Other debtors / guarantors
# ||||||||||:A101
#            Other installment plans
# |||||||||||:A143
#             LEAF: 1
# |||||||||||:A141
#             LEAF: 2
# |||||||||:A62
#           LEAF: 1
# |||||||||:A61
#           LEAF: 1
# |||||||||:A65
#           LEAF: 1
# |||||:A94
#       LEAF: 1
# |||||:A92
#       Other installment plans
# ||||||:A143
#        Housing
# |||||||:A151
#         LEAF: 1
# |||||||:A152
#         Savings account/bonds
# ||||||||:A62
#          LEAF: 1
# ||||||||:A61
#          LEAF: 1
# ||||||||:A64
#          LEAF: 1
# ||||||||:A65
#          LEAF: 2
# ||||||:A142
#        LEAF: 1
# ||||:A13
#      LEAF: 1
# ||||:A12
#      Personal status and sex
# |||||:A93
#       Purpose
# ||||||:A49
#        LEAF: 2
# ||||||:A40
#        LEAF: 1
# ||||||:A42
#        LEAF: 1
# |||||:A94
#       Savings account/bonds
# ||||||:A62
#        LEAF: 2
# ||||||:A61
#        LEAF: 1
# |||||:A92
#       Housing
# ||||||:A151
#        LEAF: 2
# ||||||:A152
#        Other debtors / guarantors
# |||||||:A101
#         Other installment plans
# ||||||||:A143
#          Purpose
# |||||||||:A45
#           LEAF: 1
# |||||||||:A42
#           LEAF: 2
# |||||||||:A43
#           Present employment since
# ||||||||||:A73
#            LEAF: 1
# ||||||||||:A75
#            LEAF: 1
# ||||||||||:A72
#            LEAF: 2
# |||||:A91
#       Present employment since
# ||||||:A73
#        LEAF: 1
# ||||||:A74
#        LEAF: 2
# ||:A191
#    Savings account/bonds
# |||:A61
#     Status of existing checking account
# ||||:A11
#      Other debtors / guarantors
# |||||:A102
#       foreign worker
# ||||||:A201
#        Present employment since
# |||||||:A73
#         Property
# ||||||||:A122
#          LEAF: 1
# ||||||||:A123
#          LEAF: 2
# |||||||:A75
#         LEAF: 2
# |||||:A103
#       LEAF: 1
# |||||:A101
#       Property
# ||||||:A121
#        Purpose
# |||||||:A40
#         Personal status and sex
# ||||||||:A93
#          Other installment plans
# |||||||||:A143
#           Housing
# ||||||||||:A152
#            Present employment since
# |||||||||||:A72
#             LEAF: 1
# |||||||||||:A74
#             LEAF: 2
# |||||||:A44
#         LEAF: 1
# |||||||:A42
#         Present employment since
# ||||||||:A73
#          foreign worker
# |||||||||:A201
#           Personal status and sex
# ||||||||||:A93
#            LEAF: 1
# ||||||||||:A92
#            LEAF: 2
# ||||||||:A74
#          LEAF: 2
# |||||||:A43
#         foreign worker
# ||||||||:A201
#          Personal status and sex
# |||||||||:A93
#           LEAF: 1
# |||||||||:A94
#           LEAF: 2
# |||||||||:A92
#           LEAF: 2
# ||||||||:A202
#          LEAF: 1
# ||||||:A122
#        Housing
# |||||||:A151
#         Other installment plans
# ||||||||:A143
#          Present employment since
# |||||||||:A72
#           LEAF: 2
# |||||||||:A74
#           LEAF: 2
# |||||||||:A75
#           LEAF: 1
# |||||||:A152
#         Personal status and sex
# ||||||||:A93
#          Purpose
# |||||||||:A42
#           Present employment since
# ||||||||||:A73
#            LEAF: 1
# ||||||||||:A74
#            LEAF: 2
# ||||||||||:A75
#            LEAF: 2
# |||||||||:A41
#           Other installment plans
# ||||||||||:A143
#            Present employment since
# |||||||||||:A73
#             LEAF: 2
# |||||||||||:A74
#             LEAF: 1
# ||||||||:A91
#          LEAF: 2
# ||||||||:A92
#          LEAF: 2
# ||||||:A124
#        foreign worker
# |||||||:A201
#         Housing
# ||||||||:A153
#          Personal status and sex
# |||||||||:A93
#           Present employment since
# ||||||||||:A72
#            LEAF: 1
# ||||||||||:A74
#            LEAF: 2
# ||||||||||:A75
#            LEAF: 1
# ||||||||||:A71
#            LEAF: 1
# ||||||||||:A73
#            LEAF: 2
# ||||||:A123
#        Other installment plans
# |||||||:A141
#         Present employment since
# ||||||||:A73
#          Personal status and sex
# |||||||||:A92
#           Housing
# ||||||||||:A151
#            LEAF: 2
# ||||||||||:A152
#            LEAF: 1
# |||||||:A143
#         foreign worker
# ||||||||:A201
#          Purpose
# |||||||||:A40
#           Present employment since
# ||||||||||:A73
#            LEAF: 1
# ||||||||||:A74
#            LEAF: 2
# ||||||||||:A71
#            LEAF: 1
# |||||||||:A44
#           LEAF: 2
# |||||||||:A42
#           Housing
# ||||||||||:A151
#            Present employment since
# |||||||||||:A72
#             LEAF: 1
# |||||||||||:A73
#             LEAF: 2
# ||||||||||:A152
#            LEAF: 2
# |||||||||:A43
#           Housing
# ||||||||||:A151
#            LEAF: 2
# ||||||||||:A152
#            Present employment since
# |||||||||||:A72
#             LEAF: 2
# |||||||||||:A75
#             LEAF: 1
# |||||||||||:A73
#             LEAF: 1
# |||||||:A142
#         LEAF: 1
# ||||:A14
#      Present employment since
# |||||:A73
#       Other debtors / guarantors
# ||||||:A103
#        LEAF: 1
# ||||||:A101
#        Personal status and sex
# |||||||:A93
#         LEAF: 1
# |||||||:A94
#         LEAF: 1
# |||||||:A92
#         Other installment plans
# ||||||||:A143
#          Property
# |||||||||:A121
#           Housing
# ||||||||||:A151
#            LEAF: 2
# ||||||||||:A152
#            LEAF: 1
# ||||||||:A141
#          LEAF: 1
# |||||:A74
#       Other debtors / guarantors
# ||||||:A101
#        Other installment plans
# |||||||:A141
#         LEAF: 1
# |||||||:A143
#         Purpose
# ||||||||:A49
#          LEAF: 1
# ||||||||:A41
#          LEAF: 1
# ||||||||:A43
#          Personal status and sex
# |||||||||:A93
#           Property
# ||||||||||:A122
#            LEAF: 1
# ||||||||||:A123
#            LEAF: 2
# |||||||||:A94
#           LEAF: 1
# |||||:A75
#       LEAF: 1
# |||||:A71
#       LEAF: 2
# |||||:A72
#       Other installment plans
# ||||||:A141
#        LEAF: 1
# ||||||:A143
#        foreign worker
# |||||||:A201
#         Property
# ||||||||:A121
#          Personal status and sex
# |||||||||:A93
#           LEAF: 1
# |||||||||:A94
#           LEAF: 1
# |||||||||:A92
#           Purpose
# ||||||||||:A45
#            LEAF: 2
# ||||||||||:A43
#            LEAF: 1
# ||||||||:A122
#          LEAF: 2
# ||||||||:A124
#          LEAF: 1
# ||||||||:A123
#          Personal status and sex
# |||||||||:A92
#           Purpose
# ||||||||||:A42
#            LEAF: 2
# ||||||||||:A43
#            LEAF: 1
# ||||:A13
#      Purpose
# |||||:A40
#       foreign worker
# ||||||:A201
#        Other installment plans
# |||||||:A141
#         LEAF: 2
# |||||||:A143
#         LEAF: 1
# |||||:A42
#       LEAF: 1
# |||||:A43
#       Personal status and sex
# ||||||:A93
#        Present employment since
# |||||||:A73
#         Other installment plans
# ||||||||:A143
#          Property
# |||||||||:A123
#           Other debtors / guarantors
# ||||||||||:A101
#            Housing
# |||||||||||:A152
#             foreign worker
# ||||||||||||:A201
#              LEAF: 2
# ||||||||:A142
#          LEAF: 2
# |||||||:A74
#         LEAF: 1
# ||||||:A94
#        LEAF: 1
# ||||:A12
#      Other installment plans
# |||||:A141
#       LEAF: 2
# |||||:A143
#       foreign worker
# ||||||:A201
#        Purpose
# |||||||:A40
#         Personal status and sex
# ||||||||:A93
#          LEAF: 1
# ||||||||:A92
#          LEAF: 2
# ||||||||:A91
#          LEAF: 2
# |||||||:A46
#         Housing
# ||||||||:A153
#          LEAF: 2
# ||||||||:A152
#          LEAF: 1
# |||||||:A49
#         LEAF: 2
# |||||||:A45
#         LEAF: 2
# |||||||:A42
#         Personal status and sex
# ||||||||:A94
#          LEAF: 1
# ||||||||:A92
#          Housing
# |||||||||:A151
#           LEAF: 1
# |||||||||:A152
#           LEAF: 2
# |||||||:A41
#         LEAF: 1
# |||||||:A43
#         Property
# ||||||||:A121
#          Present employment since
# |||||||||:A72
#           Personal status and sex
# ||||||||||:A94
#            LEAF: 2
# ||||||||||:A92
#            LEAF: 1
# |||||||||:A74
#           Other debtors / guarantors
# ||||||||||:A101
#            Housing
# |||||||||||:A152
#             Personal status and sex
# ||||||||||||:A93
#              LEAF: 2
# ||||||||||||:A92
#              LEAF: 2
# |||||||||:A75
#           LEAF: 1
# |||||||||:A73
#           Housing
# ||||||||||:A152
#            Personal status and sex
# |||||||||||:A93
#             LEAF: 1
# |||||||||||:A92
#             LEAF: 2
# ||||||||:A123
#          Personal status and sex
# |||||||||:A93
#           Present employment since
# ||||||||||:A74
#            LEAF: 1
# ||||||||||:A75
#            Housing
# |||||||||||:A152
#             Other debtors / guarantors
# ||||||||||||:A101
#              LEAF: 2
# ||||||:A202
#        Present employment since
# |||||||:A73
#         Property
# ||||||||:A121
#          LEAF: 1
# ||||||||:A123
#          LEAF: 2
# |||||||:A74
#         LEAF: 1
# |||||:A142
#       LEAF: 2
# |||:A62
#     Present employment since
# ||||:A73
#      foreign worker
# |||||:A201
#       Other debtors / guarantors
# ||||||:A102
#        Status of existing checking account
# |||||||:A14
#         LEAF: 1
# |||||||:A12
#         LEAF: 2
# ||||||:A103
#        Property
# |||||||:A121
#         LEAF: 1
# |||||||:A122
#         LEAF: 2
# ||||||:A101
#        Status of existing checking account
# |||||||:A12
#         Personal status and sex
# ||||||||:A93
#          LEAF: 1
# ||||||||:A94
#          LEAF: 2
# |||||:A202
#       LEAF: 1
# ||||:A74
#      Property
# |||||:A122
#       LEAF: 2
# |||||:A124
#       LEAF: 1
# |||||:A123
#       LEAF: 1
# ||||:A75
#      Personal status and sex
# |||||:A93
#       Purpose
# ||||||:A42
#        LEAF: 1
# ||||||:A43
#        LEAF: 2
# |||||:A91
#       LEAF: 1
# ||||:A71
#      Personal status and sex
# |||||:A91
#       LEAF: 2
# |||||:A92
#       Status of existing checking account
# ||||||:A11
#        LEAF: 2
# ||||||:A14
#        LEAF: 1
# ||||:A72
#      Personal status and sex
# |||||:A93
#       LEAF: 1
# |||||:A92
#       Status of existing checking account
# ||||||:A14
#        LEAF: 1
# ||||||:A12
#        LEAF: 2
# |||:A63
#     Purpose
# ||||:A44
#      LEAF: 1
# ||||:A42
#      LEAF: 1
# ||||:A40
#      Housing
# |||||:A153
#       LEAF: 1
# |||||:A152
#       Other installment plans
# ||||||:A143
#        Property
# |||||||:A122
#         Personal status and sex
# ||||||||:A93
#          LEAF: 1
# ||||||||:A92
#          LEAF: 2
# ||||:A41
#      Present employment since
# |||||:A72
#       LEAF: 2
# |||||:A73
#       LEAF: 1
# ||||:A43
#      LEAF: 1
# |||:A64
#     LEAF: 1
# |||:A65
#     Other installment plans
# ||||:A141
#      Purpose
# |||||:A49
#       LEAF: 2
# |||||:A41
#       LEAF: 1
# ||||:A143
#      foreign worker
# |||||:A201
#       Property
# ||||||:A121
#        Housing
# |||||||:A151
#         Personal status and sex
# ||||||||:A92
#          Purpose
# |||||||||:A40
#           LEAF: 2
# |||||||||:A42
#           LEAF: 2
# |||||||||:A41
#           LEAF: 1
# |||||||:A152
#         LEAF: 1
# ||||||:A122
#        Status of existing checking account
# |||||||:A11
#         LEAF: 2
# |||||||:A14
#         LEAF: 1
# |||||||:A12
#         Purpose
# ||||||||:A40
#          LEAF: 2
# ||||||||:A43
#          LEAF: 1
# ||||||:A124
#        Personal status and sex
# |||||||:A93
#         Other debtors / guarantors
# ||||||||:A101
#          Purpose
# |||||||||:A40
#           LEAF: 1
# |||||||||:A41
#           LEAF: 2
# |||||||||:A46
#           LEAF: 1
# |||||||:A92
#         LEAF: 2
# ||||||:A123
#        Present employment since
# |||||||:A72
#         LEAF: 1
# |||||||:A74
#         LEAF: 1
# |||||||:A75
#         LEAF: 1
# |||||||:A73
#         Housing
# ||||||||:A151
#          LEAF: 2
# ||||||||:A152
#          Other debtors / guarantors
# |||||||||:A101
#           Purpose
# ||||||||||:A43
#            LEAF: 1
# ||||||||||:A40
#            LEAF: 2
# ||||||||||:A42
#            LEAF: 2
# ||||||||||:A41
#            LEAF: 1
# ||||||||||:A46
#            LEAF: 1
# |||||:A202
#       LEAF: 1
# |:A33
#   Status of existing checking account
# ||:A11
#    LEAF: 2
# ||:A14
#    foreign worker
# |||:A201
#     Savings account/bonds
# ||||:A61
#      Other installment plans
# |||||:A141
#       Present employment since
# ||||||:A73
#        LEAF: 1
# ||||||:A72
#        LEAF: 2
# |||||:A143
#       Housing
# ||||||:A151
#        LEAF: 1
# ||||||:A153
#        LEAF: 1
# ||||||:A152
#        Personal status and sex
# |||||||:A93
#         LEAF: 1
# |||||||:A94
#         Present employment since
# ||||||||:A73
#          LEAF: 2
# ||||||||:A71
#          LEAF: 1
# |||||||:A92
#         Property
# ||||||||:A121
#          Telephone
# |||||||||:A191
#           Present employment since
# ||||||||||:A73
#            LEAF: 1
# ||||||||||:A74
#            LEAF: 2
# ||||||||:A123
#          LEAF: 1
# |||||||:A91
#         LEAF: 2
# ||||:A62
#      LEAF: 1
# ||||:A63
#      LEAF: 1
# ||||:A64
#      Housing
# |||||:A153
#       LEAF: 2
# |||||:A152
#       LEAF: 1
# ||||:A65
#      Personal status and sex
# |||||:A93
#       Telephone
# ||||||:A192
#        Other installment plans
# |||||||:A143
#         Housing
# ||||||||:A151
#          LEAF: 2
# ||||||||:A152
#          LEAF: 1
# ||||||:A191
#        LEAF: 1
# |||||:A94
#       LEAF: 1
# ||:A13
#    LEAF: 1
# ||:A12
#    Housing
# |||:A151
#     LEAF: 1
# |||:A153
#     Savings account/bonds
# ||||:A61
#      LEAF: 2
# ||||:A62
#      LEAF: 1
# |||:A152
#     Telephone
# ||||:A192
#      LEAF: 1
# ||||:A191
#      Property
# |||||:A122
#       Other installment plans
# ||||||:A143
#        LEAF: 1
# ||||||:A142
#        Purpose
# |||||||:A45
#         LEAF: 2
# |||||||:A49
#         LEAF: 1
# |||||:A123
#       LEAF: 1
# |:A34
#   Other debtors / guarantors
# ||:A102
#    Savings account/bonds
# |||:A61
#     Telephone
# ||||:A192
#      LEAF: 2
# ||||:A191
#      Other installment plans
# |||||:A141
#       LEAF: 1
# |||||:A143
#       foreign worker
# ||||||:A201
#        Property
# |||||||:A121
#         Purpose
# ||||||||:A40
#          LEAF: 2
# ||||||||:A43
#          LEAF: 1
# |||||||:A123
#         LEAF: 1
# |||:A65
#     LEAF: 1
# ||:A103
#    Personal status and sex
# |||:A93
#     Other installment plans
# ||||:A143
#      Status of existing checking account
# |||||:A11
#       LEAF: 1
# |||||:A12
#       foreign worker
# ||||||:A201
#        Savings account/bonds
# |||||||:A61
#         Purpose
# ||||||||:A43
#          Telephone
# |||||||||:A191
#           Property
# ||||||||||:A121
#            Present employment since
# |||||||||||:A72
#             LEAF: 1
# |||||||||||:A74
#             LEAF: 2
# ||||:A141
#      Telephone
# |||||:A192
#       foreign worker
# ||||||:A201
#        Purpose
# |||||||:A40
#         LEAF: 2
# |||||||:A43
#         LEAF: 1
# |||||:A191
#       LEAF: 2
# |||:A94
#     Telephone
# ||||:A192
#      LEAF: 1
# ||||:A191
#      LEAF: 2
# ||:A101
#    Status of existing checking account
# |||:A11
#     Other installment plans
# ||||:A141
#      LEAF: 2
# ||||:A143
#      Present employment since
# |||||:A73
#       Savings account/bonds
# ||||||:A61
#        Housing
# |||||||:A151
#         Property
# ||||||||:A121
#          Personal status and sex
# |||||||||:A93
#           LEAF: 1
# |||||||||:A92
#           LEAF: 2
# ||||||||:A122
#          LEAF: 1
# |||||||:A152
#         LEAF: 1
# ||||||:A63
#        LEAF: 2
# |||||:A74
#       Purpose
# ||||||:A49
#        LEAF: 1
# ||||||:A40
#        LEAF: 1
# ||||||:A41
#        Savings account/bonds
# |||||||:A62
#         LEAF: 1
# |||||||:A61
#         LEAF: 2
# ||||||:A43
#        LEAF: 1
# |||||:A75
#       foreign worker
# ||||||:A201
#        Purpose
# |||||||:A40
#         Personal status and sex
# ||||||||:A93
#          Housing
# |||||||||:A152
#           Property
# ||||||||||:A121
#            LEAF: 1
# ||||||||||:A122
#            LEAF: 2
# ||||||||:A92
#          LEAF: 1
# |||||||:A42
#         LEAF: 1
# |||||||:A41
#         Property
# ||||||||:A121
#          LEAF: 1
# ||||||||:A122
#          LEAF: 1
# ||||||||:A124
#          LEAF: 2
# |||||||:A43
#         LEAF: 1
# |||||:A72
#       LEAF: 1
# |||:A14
#     foreign worker
# ||||:A201
#      Present employment since
# |||||:A73
#       Personal status and sex
# ||||||:A93
#        Savings account/bonds
# |||||||:A61
#         Other installment plans
# ||||||||:A141
#          Purpose
# |||||||||:A40
#           LEAF: 2
# |||||||||:A46
#           LEAF: 1
# ||||||||:A143
#          LEAF: 1
# |||||||:A63
#         Housing
# ||||||||:A153
#          LEAF: 2
# ||||||||:A152
#          LEAF: 1
# |||||||:A64
#         LEAF: 1
# |||||||:A65
#         LEAF: 1
# ||||||:A94
#        LEAF: 1
# ||||||:A92
#        Other installment plans
# |||||||:A143
#         Savings account/bonds
# ||||||||:A62
#          Purpose
# |||||||||:A43
#           LEAF: 1
# |||||||||:A46
#           Housing
# ||||||||||:A152
#            Telephone
# |||||||||||:A191
#             Property
# ||||||||||||:A121
#              LEAF: 2
# ||||||||||||:A123
#              LEAF: 2
# ||||||||:A61
#          LEAF: 1
# |||||||:A142
#         LEAF: 2
# |||||:A74
#       Purpose
# ||||||:A43
#        LEAF: 1
# ||||||:A40
#        Personal status and sex
# |||||||:A93
#         Savings account/bonds
# ||||||||:A61
#          Housing
# |||||||||:A152
#           Property
# ||||||||||:A122
#            LEAF: 2
# ||||||||||:A123
#            LEAF: 1
# |||||||:A94
#         LEAF: 1
# |||||||:A92
#         LEAF: 1
# ||||||:A45
#        LEAF: 1
# ||||||:A42
#        LEAF: 1
# ||||||:A41
#        LEAF: 1
# ||||||:A46
#        LEAF: 1
# |||||:A75
#       LEAF: 1
# |||||:A72
#       Telephone
# ||||||:A192
#        Housing
# |||||||:A151
#         LEAF: 2
# |||||||:A153
#         LEAF: 1
# |||||||:A152
#         LEAF: 1
# ||||||:A191
#        LEAF: 1
# ||||:A202
#      LEAF: 1
# |||:A13
#     Property
# ||||:A121
#      Personal status and sex
# |||||:A94
#       LEAF: 2
# |||||:A91
#       LEAF: 1
# ||||:A122
#      LEAF: 1
# ||||:A124
#      LEAF: 1
# ||||:A123
#      Housing
# |||||:A151
#       LEAF: 2
# |||||:A152
#       LEAF: 1
# |||:A12
#     foreign worker
# ||||:A201
#      Savings account/bonds
# |||||:A61
#       Housing
# ||||||:A151
#        LEAF: 1
# ||||||:A153
#        LEAF: 1
# ||||||:A152
#        Present employment since
# |||||||:A73
#         Other installment plans
# ||||||||:A143
#          Telephone
# |||||||||:A192
#           LEAF: 1
# |||||||||:A191
#           LEAF: 2
# |||||||:A74
#         Property
# ||||||||:A122
#          Other installment plans
# |||||||||:A143
#           Purpose
# ||||||||||:A44
#            LEAF: 1
# ||||||||||:A42
#            LEAF: 2
# |||||||:A75
#         Property
# ||||||||:A121
#          Personal status and sex
# |||||||||:A93
#           LEAF: 1
# |||||||||:A91
#           LEAF: 2
# ||||||||:A122
#          LEAF: 1
# ||||||||:A124
#          LEAF: 1
# ||||||||:A123
#          LEAF: 2
# |||||||:A72
#         LEAF: 2
# |||||:A62
#       LEAF: 1
# |||||:A63
#       LEAF: 1
# |||||:A64
#       Housing
# ||||||:A151
#        LEAF: 1
# ||||||:A153
#        LEAF: 2
# ||||||:A152
#        LEAF: 1
# |||||:A65
#       LEAF: 1
# :A172
#  foreign worker
# |:A201
#   Other debtors / guarantors
# ||:A102
#    Status of existing checking account
# |||:A11
#     Property
# ||||:A122
#      LEAF: 1
# ||||:A124
#      LEAF: 2
# |||:A14
#     LEAF: 2
# ||:A103
#    Purpose
# |||:A40
#     Credit history
# ||||:A31
#      LEAF: 1
# ||||:A32
#      Other installment plans
# |||||:A143
#       Housing
# ||||||:A152
#        Present employment since
# |||||||:A73
#         LEAF: 2
# |||||||:A72
#         LEAF: 1
# |||:A42
#     LEAF: 1
# |||:A410
#     LEAF: 1
# |||:A43
#     Savings account/bonds
# ||||:A61
#      Housing
# |||||:A151
#       LEAF: 2
# |||||:A152
#       LEAF: 1
# ||:A101
#    Credit history
# |||:A31
#     Purpose
# ||||:A48
#      LEAF: 1
# ||||:A43
#      Status of existing checking account
# |||||:A11
#       LEAF: 2
# |||||:A14
#       LEAF: 1
# |||||:A13
#       LEAF: 1
# ||||:A40
#      LEAF: 2
# ||||:A46
#      LEAF: 2
# |||:A30
#     Personal status and sex
# ||||:A93
#      Purpose
# |||||:A49
#       LEAF: 2
# |||||:A41
#       LEAF: 1
# |||||:A48
#       LEAF: 1
# ||||:A94
#      LEAF: 1
# ||||:A92
#      LEAF: 2
# |||:A32
#     Housing
# ||||:A151
#      Purpose
# |||||:A43
#       Personal status and sex
# ||||||:A93
#        Status of existing checking account
# |||||||:A11
#         Property
# ||||||||:A121
#          Other installment plans
# |||||||||:A143
#           LEAF: 2
# |||||||||:A141
#           LEAF: 1
# ||||||:A94
#        LEAF: 1
# ||||||:A92
#        LEAF: 1
# |||||:A40
#       Property
# ||||||:A121
#        LEAF: 1
# ||||||:A122
#        LEAF: 2
# |||||:A49
#       Status of existing checking account
# ||||||:A14
#        LEAF: 1
# ||||||:A12
#        Personal status and sex
# |||||||:A92
#         LEAF: 1
# |||||||:A91
#         LEAF: 2
# |||||:A45
#       Telephone
# ||||||:A191
#        Present employment since
# |||||||:A72
#         LEAF: 2
# |||||||:A74
#         LEAF: 1
# |||||:A42
#       Personal status and sex
# ||||||:A93
#        LEAF: 1
# ||||||:A91
#        LEAF: 1
# ||||||:A92
#        Status of existing checking account
# |||||||:A11
#         Present employment since
# ||||||||:A72
#          LEAF: 2
# ||||||||:A74
#          LEAF: 1
# |||||||:A14
#         Savings account/bonds
# ||||||||:A63
#          LEAF: 2
# ||||||||:A61
#          LEAF: 1
# ||||||||:A65
#          LEAF: 1
# |||||||:A12
#         LEAF: 1
# |||||:A41
#       LEAF: 1
# |||||:A46
#       LEAF: 2
# ||||:A153
#      LEAF: 1
# ||||:A152
#      Property
# |||||:A121
#       Personal status and sex
# ||||||:A93
#        Status of existing checking account
# |||||||:A11
#         Purpose
# ||||||||:A40
#          LEAF: 2
# ||||||||:A42
#          LEAF: 1
# ||||||||:A43
#          Savings account/bonds
# |||||||||:A61
#           Other installment plans
# ||||||||||:A143
#            LEAF: 1
# ||||||||||:A142
#            LEAF: 2
# |||||||:A14
#         LEAF: 1
# |||||||:A12
#         Telephone
# ||||||||:A191
#          Present employment since
# |||||||||:A72
#           LEAF: 2
# |||||||||:A74
#           LEAF: 1
# |||||||||:A73
#           Savings account/bonds
# ||||||||||:A63
#            LEAF: 2
# ||||||||||:A61
#            LEAF: 1
# ||||||:A94
#        LEAF: 1
# ||||||:A92
#        Purpose
# |||||||:A45
#         LEAF: 1
# |||||||:A49
#         LEAF: 1
# |||||||:A40
#         Status of existing checking account
# ||||||||:A11
#          Savings account/bonds
# |||||||||:A61
#           Other installment plans
# ||||||||||:A143
#            Present employment since
# |||||||||||:A72
#             Telephone
# ||||||||||||:A192
#              LEAF: 2
# ||||||||||||:A191
#              LEAF: 2
# |||||||||||:A73
#             LEAF: 2
# ||||||||:A12
#          LEAF: 1
# |||||||:A42
#         LEAF: 1
# |||||||:A43
#         Status of existing checking account
# ||||||||:A14
#          LEAF: 1
# ||||||||:A13
#          LEAF: 2
# ||||||||:A12
#          LEAF: 1
# ||||||:A91
#        LEAF: 1
# |||||:A122
#       Purpose
# ||||||:A49
#        LEAF: 1
# ||||||:A40
#        Personal status and sex
# |||||||:A93
#         LEAF: 1
# |||||||:A92
#         LEAF: 2
# ||||||:A42
#        Personal status and sex
# |||||||:A93
#         LEAF: 2
# |||||||:A91
#         Present employment since
# ||||||||:A72
#          LEAF: 2
# ||||||||:A75
#          LEAF: 1
# |||||||:A92
#         LEAF: 1
# ||||||:A43
#        LEAF: 1
# |||||:A124
#       LEAF: 2
# |||||:A123
#       Telephone
# ||||||:A192
#        Savings account/bonds
# |||||||:A61
#         LEAF: 2
# |||||||:A62
#         LEAF: 1
# ||||||:A191
#        Present employment since
# |||||||:A73
#         Purpose
# ||||||||:A49
#          LEAF: 1
# ||||||||:A40
#          LEAF: 2
# ||||||||:A42
#          LEAF: 1
# ||||||||:A43
#          Status of existing checking account
# |||||||||:A11
#           LEAF: 2
# |||||||||:A13
#           LEAF: 1
# |||||||:A74
#         LEAF: 2
# |||||||:A75
#         Personal status and sex
# ||||||||:A93
#          Purpose
# |||||||||:A45
#           LEAF: 1
# |||||||||:A43
#           LEAF: 1
# |||||||||:A40
#           LEAF: 2
# |||||||||:A46
#           LEAF: 2
# |||||||:A72
#         Status of existing checking account
# ||||||||:A11
#          LEAF: 2
# ||||||||:A14
#          LEAF: 1
# |||:A33
#     Telephone
# ||||:A192
#      Other installment plans
# |||||:A143
#       Savings account/bonds
# ||||||:A61
#        Present employment since
# |||||||:A73
#         LEAF: 1
# |||||||:A74
#         LEAF: 1
# |||||||:A72
#         LEAF: 2
# ||||||:A62
#        LEAF: 1
# ||||:A191
#      Housing
# |||||:A152
#       Other installment plans
# ||||||:A141
#        Present employment since
# |||||||:A72
#         Property
# ||||||||:A121
#          LEAF: 2
# ||||||||:A122
#          LEAF: 1
# ||||||:A143
#        Purpose
# |||||||:A40
#         Savings account/bonds
# ||||||||:A61
#          Personal status and sex
# |||||||||:A93
#           Present employment since
# ||||||||||:A73
#            LEAF: 1
# ||||||||||:A75
#            LEAF: 2
# |||||||:A42
#         LEAF: 1
# |||||||:A49
#         LEAF: 1
# |||||||:A41
#         LEAF: 1
# |||||||:A43
#         LEAF: 1
# ||||||:A142
#        LEAF: 1
# |||:A34
#     Telephone
# ||||:A192
#      LEAF: 1
# ||||:A191
#      Savings account/bonds
# |||||:A61
#       Present employment since
# ||||||:A73
#        LEAF: 1
# ||||||:A74
#        LEAF: 1
# ||||||:A75
#        Status of existing checking account
# |||||||:A11
#         Personal status and sex
# ||||||||:A93
#          Purpose
# |||||||||:A40
#           Housing
# ||||||||||:A152
#            Other installment plans
# |||||||||||:A143
#             Property
# ||||||||||||:A121
#              LEAF: 2
# ||||||||||||:A123
#              LEAF: 2
# ||||||||:A92
#          LEAF: 2
# |||||||:A14
#         LEAF: 1
# |||||||:A12
#         LEAF: 1
# ||||||:A72
#        Personal status and sex
# |||||||:A93
#         Other installment plans
# ||||||||:A141
#          LEAF: 1
# ||||||||:A143
#          LEAF: 2
# |||||||:A92
#         Other installment plans
# ||||||||:A141
#          LEAF: 2
# ||||||||:A143
#          LEAF: 1
# |||||:A62
#       Housing
# ||||||:A151
#        LEAF: 2
# ||||||:A152
#        LEAF: 1
# |||||:A63
#       Personal status and sex
# ||||||:A93
#        LEAF: 2
# ||||||:A94
#        LEAF: 1
# |||||:A64
#       LEAF: 1
# |||||:A65
#       Personal status and sex
# ||||||:A93
#        Present employment since
# |||||||:A72
#         LEAF: 1
# |||||||:A74
#         LEAF: 2
# |||||||:A75
#         LEAF: 1
# |||||||:A73
#         LEAF: 1
# ||||||:A92
#        LEAF: 1
# |:A202
#   LEAF: 1
# 0.61

# %%
import pandas
import random
import math
from sklearn import cross_validation
from collections import Counter

#the class with functions to be used as entry points when
#either training (fit) or predicting (predict) with the
#decision tree algorithm
class DTree:
    def fit(self,Data,predictor_columns_data,target_column_data):
        self.__root_node = DNode(predictor_columns_data,target_column_data)
        self.__root_node.train()
        
    def predict(self,df_of_new_examples):
        #apply the predict function to the whole series, one at a time, this returns the series with the return vals
        predictions = df_of_new_examples.apply(self.__root_node.predict,axis=1)
        return predictions
        
    def print_tree(self):
        self.__root_node.print_node()
        

#A class for representing non-leaf nodes in the decision tree
class DNode:
    
    #when we create this node, we pass it training examples to be used at this point
    #the predictor columns of these training examples is in predictor_columns_data
    #the corresponding target values to those predictor columns are in target_column_data
    def __init__(self,predictor_columns_data,target_column_data):
        
        self.__attribute = ''  #the attribute used to sort examples at this node
        self.__predictor_columns = predictor_columns_data #the training examples that have been sorted to this node
        self.__target_column = target_column_data #the corresponding target values for the training examples
        self.__child_nodes = {} #dictionary of the child nodes of this node, indexed by the value they have for self.__attribute
        self.__most_common_value_here = '' #for keeping track of which target value is most common among the examples at this node. This is used to make a decision when there's no appropriate child node to follow
        
    #this should use the training data to determine the best attribute to use
    #as is, it just chooses one at random, but you will fix it to use information gain
    def choose_attribute(self):
        #self.__attribute = random.choice(self.__predictor_columns.columns.values) #what a terrible way to choose the attribute!
        #Me,Gary,Yee Jun discussed and came out with this code. However, we have problems while integrating it into 
        #Choose_Attribute. It works perfectly fine when we run it seperately and the highest information gain attribute should be
        #Status of Existing Checking Account.
        
        
        min_exp=100
        for i in self.__predictor_columns:
            print(i)
            p_1 = Counter(subset1(i))
            p_2 = Counter(subset2(i))
            print(p_1)
            print(p_2)

            expected_entropy=0
    
            for k in p_1.keys():
                x = p_1.get(k)
                y = p_2.get(k)
                print(x)
                print(y)

                entropy = -(x/(x+y)) * math.log((x/(x+y)), 2) - (y/(x+y)) * math.log((y/(x+y)), 2)
                print(entropy)
                expected_entropy += ((x+y)/len(self.__target_column)) * entropy
                #expected_count += expected_entropy
    
                print(expected_entropy)
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@")
            if expected_entropy<min_exp:
                min_exp=expected_entropy
                print(min_exp)
                print("######################")
                self.__attribute=i
                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
       
    """
    Oct09-12 2016
    My previous choose_attribute
    
   
    def choose_attribute(self):
            smallestExpEnt=100
            expEntropy=0
        #for i in a:
        #self.__attribute = random.choice(self.__predictor_columns.columns.values) #what a terrible way to choose the attribute!
            for i in self.__predictor_columns:
                exp_count=Counter(self.__predictor_columns[i]) #count the frequencies in the column data
        
                exp_values=exp_count.values() #Get the freq values in the column data
                print(exp_values)
                length_numerator=len(exp_values) #Length of [freq values] eg: {3,4,5}, length = 3
        
                expEntropy+=(length_numerator/len(self.__target_column))*(Entropy(self.__target_column))#calling entropy function
                print(expEntropy)
            if expEntropy < smallestExpEnt:
                smallestExpEnt=expEntropy
                self.__attribute=i
                print(self.__attribute)
                print("@@@@@@@@@@@@@")
                
    Comment: It works fine, but I didn't subset the attributes_to_use columns based on "Creditability"==1 or "Creditability==2",
    the concept of expected entropy is Wrong here.
    """            
                                        
    def train(self):
        self.choose_attribute() #'best' attribute at this node
        
        #in case we need to make a decision here because we don't have any children with a particular attribute value    
        self.__most_common_value_here = self.__target_column.value_counts().idxmax()
        
        #gets all the values that these examples have in our chosen column
        attribute_values_here = self.__predictor_columns[self.__attribute].unique()

        #going through all possible values this attribute can have
        #and creating the appropriate child node
        for value in attribute_values_here: 
             
            #the subset of examples with the given value
            examples_for_child_predictor_cols = self.__predictor_columns[self.__predictor_columns[self.__attribute] == value] 
            examples_for_child_target_col = self.__target_column[self.__predictor_columns[self.__attribute] == value] #target values corresponding to the subset of examples with the given value
            
            #we grabbed the values from the examples themselves, so there should
            #be at least one example that has each value, but just in case there isn't
            #I don't want to crash the program
            if examples_for_child_target_col.empty:
                print("error: we shouldn't get here")
                
            #there are no columns left to use for decisions at the child
            #so lets make a leage node based on the most common target value in those examples
            elif len(examples_for_child_predictor_cols.columns.values) == 1:  
                #create a child with the most common target value here
                leaf_child = DLeaf( self.__most_common_value_here )
                self.__child_nodes[value] = leaf_child
                
            #if all child examples have the same target value, we make a leaf node
            elif len(examples_for_child_target_col.unique()) == 1: #all child examples have same class
                leaf_child = DLeaf( examples_for_child_target_col.unique()[0] ) #make leaf with that class
                self.__child_nodes[value] = leaf_child #put the leaf in the dictionary of children nodes
                
            else: #we have a regular decision node for this attribute value
                #get rid of the column for this attribute so it can't be selected again
                examples_for_child_predictor_cols = examples_for_child_predictor_cols.drop(self.__attribute,1) 
                
                new_child = DNode(examples_for_child_predictor_cols,examples_for_child_target_col)
                new_child.train() #generate the rest of the subtree for this child
                self.__child_nodes[value] = new_child #put the new child node in the dictionary of children nodes
            

    #print out the tree - not the prettiest, but you can see it.
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end=''), #print with no newline
        print(self.__attribute)
        for attr in self.__child_nodes.keys():
            for i in range(num_indents): 
                print("|", end='')
            print(":"+attr)
            self.__child_nodes[attr].print_node(num_indents+1)
            
    #make a prediction for a single new example
    #this only makes sense to call after the tree has been build (with train())
    def predict(self,new_example):
        #look up the right branch in our dictionary of children
        if new_example[self.__attribute] in self.__child_nodes:
            node_on_corresponding_branch = self.__child_nodes[new_example[self.__attribute]]
            return node_on_corresponding_branch.predict(new_example) #recursively call predict on the child node
        else:
            return self.__most_common_value_here #there was no child, so we predict the most common class of the examples at this node
        
#class for representing a leaf node in the tree
class DLeaf:
    
    #when we create the node, all we need to know is what we're going to predict if we get here
    def __init__(self,val_in_target_col):
        self.__target_value = val_in_target_col
    
    #just returns the prediction for a new example, 
    #this was probably called from predict() of a regular node one level up in the tree
    def predict(self,new_example):
        return self.__target_value
    
    #for displaying the tree
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end='')
        print("LEAF:",self.__target_value)
        
    
#simply compares two Pandas series and returns the proportion that match
#this can be used to compute the accuracy of the prediction list against
#the actual target column
def accuracy(series1, series2):
    correct = 0.0
    for index, value in series1.iteritems():
        if value == series2.loc[index]:
            correct += 1
    return (correct/len(series1))

##Reference from: https://rosettacode.org/wiki/Entropy

def Entropy(self):
    #Email Reply from Prof.Manley.
    #Expected entropy is something you should pass an attribute column to,
    #but the expected_entropy function should also call your entropy function,
    #so you’d need to pass both a regular column and the target column to expected_entropy
    entropy=0  
    p, lens = Counter(self),float(len(self))        
    #p.values() contains dict_values of Counter. 
    #Example: counter results = [a:3,b:41,c:500], p.values() will print out [3,41,500]
    return -sum( count/lens * math.log(count/lens, 2)for count in p.values())
    ## -sum(3/(3+41+500)+ln2(3/(3+41+500))
    
def subset1(self):
    train1=train_data[train_data.Creditability==1]
    
    return train1[self]

def subset2(self):
    train2=train_data[train_data.Creditability==2]
    return train2[self]
#'''

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#####Question2:
###(15 points) Enhance the decision tree code so that the best attribute is selected based on the attribute with the highest information gain (rather than randomly as it is in the starter code).
###Discuss what you did and record the performance in your write-up.#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@


import math
credit_data= pandas.read_csv('german_credit.csv')

train_data, test_data = cross_validation.train_test_split(credit_data,test_size = 0.1)
    
attributes_to_use=['Status of existing checking account','Credit history',\
                   'Purpose','Savings account/bonds','Present employment since',\
                    'Personal status and sex','Other debtors / guarantors',\
                    'Property','Other installment plans','Housing',\
                    'Job','Telephone','foreign worker',\
                    ]
                    

my_tree = DTree() 
my_tree.fit(train_data,train_data[attributes_to_use],train_data['Creditability'])
#my_tree.print_tree()
predictions = my_tree.predict(test_data[attributes_to_use])
print(accuracy(test_data['Creditability'],predictions))

#print(subset1('Job'))

#print(subset2(train_data['Job']))
# Out:
# Status of existing checking account
# Counter({'A14': 318, 'A12': 142, 'A11': 125, 'A13': 45})
# Counter({'A11': 120, 'A12': 95, 'A14': 42, 'A13': 13})
# 125
# 120
# 0.999699542856517
# 0.2721404311109407
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 318
# 42
# 0.5197027865043055
# 0.4800215457126629
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 45
# 13
# 0.7676515870125797
# 0.5294924257645848
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 142
# 95
# 0.9714420937881119
# 0.7853055104621209
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 0.7853055104621209
# ######################
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Credit history
# Counter({'A32': 328, 'A34': 214, 'A33': 53, 'A31': 20, 'A30': 15})
# Counter({'A32': 151, 'A34': 44, 'A33': 26, 'A31': 26, 'A30': 23})
# 53
# 26
# 0.9140185106642176
# 0.0802305137138591
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 20
# 26
# 0.9876925088958034
# 0.1307125752796446
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 15
# 23
# 0.9677884628267679
# 0.17157475482121926
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 328
# 151
# 0.8991299184860375
# 0.6501116781043437
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 214
# 44
# 0.6589445953074149
# 0.8390091287591359
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Purpose
# Counter({'A43': 191, 'A40': 134, 'A42': 114, 'A41': 77, 'A49': 56, 'A46': 25, 'A45': 12, 'A44': 8, 'A48': 7, 'A410': 6})
# Counter({'A40': 82, 'A43': 57, 'A42': 50, 'A49': 32, 'A46': 21, 'A41': 12, 'A45': 6, 'A410': 5, 'A44': 4, 'A48': 1})
# 7
# 1
# 0.5435644431995964
# 0.004831683939551968
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 134
# 82
# 0.9577800211448373
# 0.2346988890143129
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 6
# 5
# 0.9940302114769565
# 0.2468481471545868
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 25
# 21
# 0.9945386816500111
# 0.2976801242166985
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 8
# 4
# 0.9182958340544896
# 0.30992406867075833
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 12
# 6
# 0.9182958340544896
# 0.3282899853518481
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 56
# 32
# 0.9456603046006402
# 0.42075454846835514
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 114
# 50
# 0.8871723027673717
# 0.5824170569726318
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 77
# 12
# 0.5705411428522261
# 0.6388372366546853
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 191
# 57
# 0.7777300323134144
# 0.8531450677810484
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Savings account/bonds
# Counter({'A61': 343, 'A65': 137, 'A62': 63, 'A63': 49, 'A64': 38})
# Counter({'A61': 195, 'A62': 33, 'A65': 26, 'A63': 10, 'A64': 6})
# 343
# 195
# 0.9447009759795819
# 0.5647212500855723
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 33
# 0.9283620723948678
# 0.6637465378076916
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 49
# 10
# 0.6565402813869459
# 0.7067864006986135
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 38
# 6
# 0.5746356978376794
# 0.7348797014817889
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 137
# 26
# 0.6331341171926692
# 0.8495473249289057
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Present employment since
# Counter({'A73': 215, 'A75': 164, 'A74': 121, 'A72': 96, 'A71': 34})
# Counter({'A73': 96, 'A72': 62, 'A75': 55, 'A74': 34, 'A71': 23})
# 215
# 96
# 0.891645809580876
# 0.30811316308850273
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 121
# 34
# 0.7589877064823829
# 0.4388277125382465
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 164
# 55
# 0.8130824340248173
# 0.6366777714842854
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 34
# 23
# 0.9729661265889026
# 0.6982989595015826
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 96
# 62
# 0.966334094295981
# 0.8679442782779881
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Personal status and sex
# Counter({'A93': 361, 'A92': 179, 'A94': 63, 'A91': 27})
# Counter({'A93': 132, 'A92': 100, 'A94': 21, 'A91': 17})
# 361
# 132
# 0.8382152593767258
# 0.4591556920808065
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 21
# 0.8112781244591328
# 0.5348749836969922
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 27
# 17
# 0.9624127354629923
# 0.581926272986294
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 179
# 100
# 0.9413663186113583
# 0.873749831755815
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other debtors / guarantors
# Counter({'A101': 573, 'A103': 36, 'A102': 21})
# Counter({'A101': 245, 'A102': 17, 'A103': 8})
# 21
# 17
# 0.9919924034538556
# 0.041884123701385015
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 36
# 8
# 0.6840384356390417
# 0.0753260027770715
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 573
# 245
# 0.8806923307005065
# 0.8757774766804206
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Property
# Counter({'A123': 208, 'A121': 201, 'A122': 148, 'A124': 73})
# Counter({'A123': 95, 'A122': 62, 'A124': 58, 'A121': 55})
# 201
# 55
# 0.7506399446452308
# 0.2135153620324212
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 148
# 62
# 0.8753918540610235
# 0.4177734613133267
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 73
# 58
# 0.9905215472195844
# 0.5619493754086218
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 208
# 95
# 0.8972078311139173
# 0.8640093452169739
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other installment plans
# Counter({'A143': 527, 'A141': 75, 'A142': 28})
# Counter({'A143': 200, 'A141': 52, 'A142': 18})
# 75
# 52
# 0.976210142437301
# 0.1377540978772636
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 527
# 200
# 0.8486924193009465
# 0.8233089743570282
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 28
# 18
# 0.9656361333706098
# 0.8726637100626372
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Housing
# Counter({'A152': 481, 'A151': 96, 'A153': 53})
# Counter({'A152': 168, 'A151': 66, 'A153': 36})
# 96
# 66
# 0.975119064940866
# 0.17552143168935586
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 53
# 36
# 0.9735190023846809
# 0.27179164414739654
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 481
# 168
# 0.8250208924672096
# 0.8667233766043065
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Job
# Counter({'A173': 398, 'A172': 133, 'A174': 85, 'A171': 14})
# Counter({'A173': 161, 'A172': 54, 'A174': 48, 'A171': 7})
# 85
# 48
# 0.9434295813183313
# 0.1394179270170423
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 14
# 7
# 0.9182958340544896
# 0.16084482981164708
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 398
# 161
# 0.8661423684553089
# 0.6988154786633333
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 133
# 54
# 0.8671271388262167
# 0.8789852286194472
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Telephone
# Counter({'A191': 372, 'A192': 258})
# Counter({'A191': 171, 'A192': 99})
# 258
# 99
# 0.8517608318524025
# 0.3378651299681196
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 372
# 171
# 0.8987681340701512
# 0.8801219041904442
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# foreign worker
# Counter({'A201': 597, 'A202': 33})
# Counter({'A201': 266, 'A202': 4})
# 597
# 266
# 0.8911163560869446
# 0.8544815725589258
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 33
# 4
# 0.49418293484978865
# 0.8747979821027504
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Credit history
# Counter({'A32': 328, 'A34': 214, 'A33': 53, 'A31': 20, 'A30': 15})
# Counter({'A32': 151, 'A34': 44, 'A33': 26, 'A31': 26, 'A30': 23})
# 53
# 26
# 0.9140185106642176
# 0.20057628428464774
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 20
# 26
# 0.9876925088958034
# 0.32678143819911154
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 15
# 23
# 0.9677884628267679
# 0.42893688705304817
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 328
# 151
# 0.8991299184860375
# 1.6252791952608592
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 214
# 44
# 0.6589445953074149
# 2.0975228218978397
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 2.0975228218978397
# ######################
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Purpose
# Counter({'A43': 191, 'A40': 134, 'A42': 114, 'A41': 77, 'A49': 56, 'A46': 25, 'A45': 12, 'A44': 8, 'A48': 7, 'A410': 6})
# Counter({'A40': 82, 'A43': 57, 'A42': 50, 'A49': 32, 'A46': 21, 'A41': 12, 'A45': 6, 'A410': 5, 'A44': 4, 'A48': 1})
# 7
# 1
# 0.5435644431995964
# 0.01207920984887992
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 134
# 82
# 0.9577800211448373
# 0.5867472225357823
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 6
# 5
# 0.9940302114769565
# 0.6171203678864671
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 25
# 21
# 0.9945386816500111
# 0.7442003105417463
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 8
# 4
# 0.9182958340544896
# 0.7748101716768959
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 12
# 6
# 0.9182958340544896
# 0.8207249633796204
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 56
# 32
# 0.9456603046006402
# 1.051886371170888
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 114
# 50
# 0.8871723027673717
# 1.4560426424315795
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 77
# 12
# 0.5705411428522261
# 1.5970930916367132
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 191
# 57
# 0.7777300323134144
# 2.1328626694526207
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Savings account/bonds
# Counter({'A61': 343, 'A65': 137, 'A62': 63, 'A63': 49, 'A64': 38})
# Counter({'A61': 195, 'A62': 33, 'A65': 26, 'A63': 10, 'A64': 6})
# 343
# 195
# 0.9447009759795819
# 1.4118031252139307
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 33
# 0.9283620723948678
# 1.6593663445192288
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 49
# 10
# 0.6565402813869459
# 1.7669660017465338
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 38
# 6
# 0.5746356978376794
# 1.8371992537044723
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 137
# 26
# 0.6331341171926692
# 2.1238683123222644
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Present employment since
# Counter({'A73': 215, 'A75': 164, 'A74': 121, 'A72': 96, 'A71': 34})
# Counter({'A73': 96, 'A72': 62, 'A75': 55, 'A74': 34, 'A71': 23})
# 215
# 96
# 0.891645809580876
# 0.7702829077212568
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 121
# 34
# 0.7589877064823829
# 1.0970692813456162
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 164
# 55
# 0.8130824340248173
# 1.5916944287107133
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 34
# 23
# 0.9729661265889026
# 1.7457473987539562
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 96
# 62
# 0.966334094295981
# 2.16986069569497
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Personal status and sex
# Counter({'A93': 361, 'A92': 179, 'A94': 63, 'A91': 27})
# Counter({'A93': 132, 'A92': 100, 'A94': 21, 'A91': 17})
# 361
# 132
# 0.8382152593767258
# 1.1478892302020163
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 21
# 0.8112781244591328
# 1.3371874592424806
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 27
# 17
# 0.9624127354629923
# 1.4548156824657352
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 179
# 100
# 0.9413663186113583
# 2.184374579389538
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other debtors / guarantors
# Counter({'A101': 573, 'A103': 36, 'A102': 21})
# Counter({'A101': 245, 'A102': 17, 'A103': 8})
# 21
# 17
# 0.9919924034538556
# 0.10471030925346254
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 36
# 8
# 0.6840384356390417
# 0.18831500694267875
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 573
# 245
# 0.8806923307005065
# 2.189443691701052
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Property
# Counter({'A123': 208, 'A121': 201, 'A122': 148, 'A124': 73})
# Counter({'A123': 95, 'A122': 62, 'A124': 58, 'A121': 55})
# 201
# 55
# 0.7506399446452308
# 0.533788405081053
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 148
# 62
# 0.8753918540610235
# 1.0444336532833167
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 73
# 58
# 0.9905215472195844
# 1.4048734385215544
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 208
# 95
# 0.8972078311139173
# 2.160023363042435
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other installment plans
# Counter({'A143': 527, 'A141': 75, 'A142': 28})
# Counter({'A143': 200, 'A141': 52, 'A142': 18})
# 75
# 52
# 0.976210142437301
# 0.34438524469315895
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 527
# 200
# 0.8486924193009465
# 2.05827243589257
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 28
# 18
# 0.9656361333706098
# 2.1816592751565924
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Housing
# Counter({'A152': 481, 'A151': 96, 'A153': 53})
# Counter({'A152': 168, 'A151': 66, 'A153': 36})
# 96
# 66
# 0.975119064940866
# 0.4388035792233897
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 53
# 36
# 0.9735190023846809
# 0.6794791103684914
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 481
# 168
# 0.8250208924672096
# 2.1668084415107662
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Job
# Counter({'A173': 398, 'A172': 133, 'A174': 85, 'A171': 14})
# Counter({'A173': 161, 'A172': 54, 'A174': 48, 'A171': 7})
# 85
# 48
# 0.9434295813183313
# 0.34854481754260574
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 14
# 7
# 0.9182958340544896
# 0.4021120745291176
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 398
# 161
# 0.8661423684553089
# 1.7470386966583333
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 133
# 54
# 0.8671271388262167
# 2.197463071548618
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Telephone
# Counter({'A191': 372, 'A192': 258})
# Counter({'A191': 171, 'A192': 99})
# 258
# 99
# 0.8517608318524025
# 0.8446628249202992
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 372
# 171
# 0.8987681340701512
# 2.2003047604761106
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# foreign worker
# Counter({'A201': 597, 'A202': 33})
# Counter({'A201': 266, 'A202': 4})
# 597
# 266
# 0.8911163560869446
# 2.1362039313973145
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 33
# 4
# 0.49418293484978865
# 2.186994955256876
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Purpose
# Counter({'A43': 191, 'A40': 134, 'A42': 114, 'A41': 77, 'A49': 56, 'A46': 25, 'A45': 12, 'A44': 8, 'A48': 7, 'A410': 6})
# Counter({'A40': 82, 'A43': 57, 'A42': 50, 'A49': 32, 'A46': 21, 'A41': 12, 'A45': 6, 'A410': 5, 'A44': 4, 'A48': 1})
# 7
# 1
# 0.5435644431995964
# 0.6212165065138244
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 134
# 82
# 0.9577800211448373
# 30.175571444697376
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 6
# 5
# 0.9940302114769565
# 31.73761891987545
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 25
# 21
# 0.9945386816500111
# 38.27315882786124
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 8
# 4
# 0.9182958340544896
# 39.84738025766893
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 12
# 6
# 0.9182958340544896
# 42.20871240238048
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 56
# 32
# 0.9456603046006402
# 54.09701337450281
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 114
# 50
# 0.8871723027673717
# 74.88219303933838
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 77
# 12
# 0.5705411428522261
# 82.13621614131668
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 191
# 57
# 0.7777300323134144
# 109.69008014327765
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Savings account/bonds
# Counter({'A61': 343, 'A65': 137, 'A62': 63, 'A63': 49, 'A64': 38})
# Counter({'A61': 195, 'A62': 33, 'A65': 26, 'A63': 10, 'A64': 6})
# 343
# 195
# 0.9447009759795819
# 72.60701786814501
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 33
# 0.9283620723948678
# 85.33884057527462
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 49
# 10
# 0.6565402813869459
# 90.87253723267888
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 38
# 6
# 0.5746356978376794
# 94.48453304765857
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 137
# 26
# 0.6331341171926692
# 109.22751320514502
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Present employment since
# Counter({'A73': 215, 'A75': 164, 'A74': 121, 'A72': 96, 'A71': 34})
# Counter({'A73': 96, 'A72': 62, 'A75': 55, 'A74': 34, 'A71': 23})
# 215
# 96
# 0.891645809580876
# 39.61454953995035
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 121
# 34
# 0.7589877064823829
# 56.420705897774546
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 164
# 55
# 0.8130824340248173
# 81.85857061940811
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 34
# 23
# 0.9729661265889026
# 89.78129479306061
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 96
# 62
# 0.966334094295981
# 111.59283577859847
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Personal status and sex
# Counter({'A93': 361, 'A92': 179, 'A94': 63, 'A91': 27})
# Counter({'A93': 132, 'A92': 100, 'A94': 21, 'A91': 17})
# 361
# 132
# 0.8382152593767258
# 59.03430326753226
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 63
# 21
# 0.8112781244591328
# 68.76964076104186
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 27
# 17
# 0.9624127354629923
# 74.81909224109495
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 179
# 100
# 0.9413663186113583
# 112.33926408289051
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other debtors / guarantors
# Counter({'A101': 573, 'A103': 36, 'A102': 21})
# Counter({'A101': 245, 'A102': 17, 'A103': 8})
# 21
# 17
# 0.9919924034538556
# 5.385101618749502
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 36
# 8
# 0.6840384356390417
# 9.684771785623479
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 573
# 245
# 0.8806923307005065
# 112.59996128748267
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Property
# Counter({'A123': 208, 'A121': 201, 'A122': 148, 'A124': 73})
# Counter({'A123': 95, 'A122': 62, 'A124': 58, 'A121': 55})
# 201
# 55
# 0.7506399446452308
# 27.45197511845415
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 148
# 62
# 0.8753918540610235
# 53.71373074028486
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 73
# 58
# 0.9905215472195844
# 72.2506339811085
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 208
# 95
# 0.8972078311139173
# 111.08691581361093
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Other installment plans
# Counter({'A143': 527, 'A141': 75, 'A142': 28})
# Counter({'A143': 200, 'A141': 52, 'A142': 18})
# 75
# 52
# 0.976210142437301
# 17.711241155648175
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 527
# 200
# 0.8486924193009465
# 105.85401098876076
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 28
# 18
# 0.9656361333706098
# 112.1996198651962
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Housing
# Counter({'A152': 481, 'A151': 96, 'A153': 53})
# Counter({'A152': 168, 'A151': 66, 'A153': 36})
# 96
# 66
# 0.975119064940866
# 22.5670412172029
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 53
# 36
# 0.9735190023846809
# 34.94463996180813
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 481
# 168
# 0.8250208924672096
# 111.43586270626798
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Job
# Counter({'A173': 398, 'A172': 133, 'A174': 85, 'A171': 14})
# Counter({'A173': 161, 'A172': 54, 'A174': 48, 'A171': 7})
# 85
# 48
# 0.9434295813183313
# 17.925162045048296
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 14
# 7
# 0.9182958340544896
# 20.680049547211766
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 398
# 161
# 0.8661423684553089
# 89.84770439957144
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 133
# 54
# 0.8671271388262167
# 113.0123865367861
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# Telephone
# Counter({'A191': 372, 'A192': 258})
# Counter({'A191': 171, 'A192': 99})
# 258
# 99
# 0.8517608318524025
# 43.439802424472525
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 372
# 171
# 0.8987681340701512
# 113.1585305387714
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# foreign worker
# Counter({'A201': 597, 'A202': 33})
# Counter({'A201': 266, 'A202': 4})
# 597
# 266
# 0.8911163560869446
# 109.86191647186189
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# 33
# 4
# 0.49418293484978865
# 112.47402627035363
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-c662d014a4cb> in <module>()
#     239
#     240 my_tree = DTree()
# --> 241 my_tree.fit(train_data,train_data[attributes_to_use],train_data['Creditability'])
#     242 #my_tree.print_tree()
#     243 predictions = my_tree.predict(test_data[attributes_to_use])
#
# <ipython-input-95-c662d014a4cb> in fit(self, Data, predictor_columns_data, target_column_data)
#      11     def fit(self,Data,predictor_columns_data,target_column_data):
#      12         self.__root_node = DNode(predictor_columns_data,target_column_data)
# ---> 13         self.__root_node.train()
#      14
#      15     def predict(self,df_of_new_examples):
#
# <ipython-input-95-c662d014a4cb> in train(self)
#     144
#     145                 new_child = DNode(examples_for_child_predictor_cols,examples_for_child_target_col)
# --> 146                 new_child.train() #generate the rest of the subtree for this child
#     147                 self.__child_nodes[value] = new_child #put the new child node in the dictionary of children nodes
#     148
#
# <ipython-input-95-c662d014a4cb> in train(self)
#     144
#     145                 new_child = DNode(examples_for_child_predictor_cols,examples_for_child_target_col)
# --> 146                 new_child.train() #generate the rest of the subtree for this child
#     147                 self.__child_nodes[value] = new_child #put the new child node in the dictionary of children nodes
#     148
#
# <ipython-input-95-c662d014a4cb> in train(self)
#     111
#     112         #gets all the values that these examples have in our chosen column
# --> 113         attribute_values_here = self.__predictor_columns[self.__attribute].unique()
#     114
#     115         #going through all possible values this attribute can have
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: ''

# %%
import pandas
import random
import math
from sklearn import cross_validation
from collections import Counter

#the class with functions to be used as entry points when
#either training (fit) or predicting (predict) with the
#decision tree algorithm
class DTree:
    def fit(self,Data,predictor_columns_data,target_column_data):
        self.__root_node = DNode(predictor_columns_data,target_column_data)
        self.__root_node.train()
        
    def predict(self,df_of_new_examples):
        #apply the predict function to the whole series, one at a time, this returns the series with the return vals
        predictions = df_of_new_examples.apply(self.__root_node.predict,axis=1)
        return predictions
        
    def print_tree(self):
        self.__root_node.print_node()
        

#A class for representing non-leaf nodes in the decision tree
class DNode:
    
    #when we create this node, we pass it training examples to be used at this point
    #the predictor columns of these training examples is in predictor_columns_data
    #the corresponding target values to those predictor columns are in target_column_data
    def __init__(self,predictor_columns_data,target_column_data):
        
        self.__attribute = ''  #the attribute used to sort examples at this node
        self.__predictor_columns = predictor_columns_data #the training examples that have been sorted to this node
        self.__target_column = target_column_data #the corresponding target values for the training examples
        self.__child_nodes = {} #dictionary of the child nodes of this node, indexed by the value they have for self.__attribute
        self.__most_common_value_here = '' #for keeping track of which target value is most common among the examples at this node. This is used to make a decision when there's no appropriate child node to follow
        
    #this should use the training data to determine the best attribute to use
    #as is, it just chooses one at random, but you will fix it to use information gain
    

    #Oct09-12 2016
    #My previous choose_attribute
    
   
    def choose_attribute(self):
            smallestExpEnt=100
            expEntropy=0
        #for i in a:
        #self.__attribute = random.choice(self.__predictor_columns.columns.values) #what a terrible way to choose the attribute!
            for i in self.__predictor_columns:
                exp_count=Counter(self.__predictor_columns[i]) #count the frequencies in the column data
        
                exp_values=exp_count.values() #Get the freq values in the column data
                print(exp_values)
                length_numerator=len(exp_values) #Length of [freq values] eg: {3,4,5}, length = 3
        
                expEntropy+=(length_numerator/len(self.__target_column))*(Entropy(self.__target_column))#calling entropy function
                print(expEntropy)
            if expEntropy < smallestExpEnt:
                smallestExpEnt=expEntropy
                self.__attribute=i
                print(self.__attribute)
                print("@@@@@@@@@@@@@")
                
    #Comment: It works fine, but I didn't subset the attributes_to_use columns based on "Creditability"==1 or "Creditability==2",
    #the concept of expected entropy is Wrong here.
              
                                        
    def train(self):
        self.choose_attribute() #'best' attribute at this node
        
        #in case we need to make a decision here because we don't have any children with a particular attribute value    
        self.__most_common_value_here = self.__target_column.value_counts().idxmax()
        
        #gets all the values that these examples have in our chosen column
        attribute_values_here = self.__predictor_columns[self.__attribute].unique()

        #going through all possible values this attribute can have
        #and creating the appropriate child node
        for value in attribute_values_here: 
             
            #the subset of examples with the given value
            examples_for_child_predictor_cols = self.__predictor_columns[self.__predictor_columns[self.__attribute] == value] 
            examples_for_child_target_col = self.__target_column[self.__predictor_columns[self.__attribute] == value] #target values corresponding to the subset of examples with the given value
            
            #we grabbed the values from the examples themselves, so there should
            #be at least one example that has each value, but just in case there isn't
            #I don't want to crash the program
            if examples_for_child_target_col.empty:
                print("error: we shouldn't get here")
                
            #there are no columns left to use for decisions at the child
            #so lets make a leage node based on the most common target value in those examples
            elif len(examples_for_child_predictor_cols.columns.values) == 1:  
                #create a child with the most common target value here
                leaf_child = DLeaf( self.__most_common_value_here )
                self.__child_nodes[value] = leaf_child
                
            #if all child examples have the same target value, we make a leaf node
            elif len(examples_for_child_target_col.unique()) == 1: #all child examples have same class
                leaf_child = DLeaf( examples_for_child_target_col.unique()[0] ) #make leaf with that class
                self.__child_nodes[value] = leaf_child #put the leaf in the dictionary of children nodes
                
            else: #we have a regular decision node for this attribute value
                #get rid of the column for this attribute so it can't be selected again
                examples_for_child_predictor_cols = examples_for_child_predictor_cols.drop(self.__attribute,1) 
                
                new_child = DNode(examples_for_child_predictor_cols,examples_for_child_target_col)
                new_child.train() #generate the rest of the subtree for this child
                self.__child_nodes[value] = new_child #put the new child node in the dictionary of children nodes
            

    #print out the tree - not the prettiest, but you can see it.
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end=''), #print with no newline
        print(self.__attribute)
        for attr in self.__child_nodes.keys():
            for i in range(num_indents): 
                print("|", end='')
            print(":"+attr)
            self.__child_nodes[attr].print_node(num_indents+1)
            
    #make a prediction for a single new example
    #this only makes sense to call after the tree has been build (with train())
    def predict(self,new_example):
        #look up the right branch in our dictionary of children
        if new_example[self.__attribute] in self.__child_nodes:
            node_on_corresponding_branch = self.__child_nodes[new_example[self.__attribute]]
            return node_on_corresponding_branch.predict(new_example) #recursively call predict on the child node
        else:
            return self.__most_common_value_here #there was no child, so we predict the most common class of the examples at this node
        
#class for representing a leaf node in the tree
class DLeaf:
    
    #when we create the node, all we need to know is what we're going to predict if we get here
    def __init__(self,val_in_target_col):
        self.__target_value = val_in_target_col
    
    #just returns the prediction for a new example, 
    #this was probably called from predict() of a regular node one level up in the tree
    def predict(self,new_example):
        return self.__target_value
    
    #for displaying the tree
    def print_node(self,num_indents = 0):
        for i in range(num_indents): 
            print(" ",end='')
        print("LEAF:",self.__target_value)
        
    
#simply compares two Pandas series and returns the proportion that match
#this can be used to compute the accuracy of the prediction list against
#the actual target column
def accuracy(series1, series2):
    correct = 0.0
    for index, value in series1.iteritems():
        if value == series2.loc[index]:
            correct += 1
    return (correct/len(series1))

##Reference from: https://rosettacode.org/wiki/Entropy

def Entropy(self):
    #Email Reply from Prof.Manley.
    #Expected entropy is something you should pass an attribute column to,
    #but the expected_entropy function should also call your entropy function,
    #so you’d need to pass both a regular column and the target column to expected_entropy
    entropy=0  
    p, lens = Counter(self),float(len(self))        
    #p.values() contains dict_values of Counter. 
    #Example: counter results = [a:3,b:41,c:500], p.values() will print out [3,41,500]
    return -sum( count/lens * math.log(count/lens, 2)for count in p.values())
    ## -sum(3/(3+41+500)+ln2(3/(3+41+500))
    
def subset1(self):
    train1=train_data[train_data.Creditability==1]
    
    return train1[self]

def subset2(self):
    train2=train_data[train_data.Creditability==2]
    return train2[self]
#'''

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#####Question3:
#####Bin up the numerical columns and use them for training and prediction
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@


import math
credit_data= pandas.read_csv('german_credit.csv')

train_data, test_data = cross_validation.train_test_split(credit_data,test_size = 0.1)
    
attributes_to_use=['Status of existing checking account','Duration in month','Credit history','Purpose','Credit amount','Savings account/bonds','Present employment since','Installment rate in percentage of disposable income','Personal status and sex','Other debtors / guarantors','Present residence since','Property','Age in years','Other installment plans','Housing','Number of existing credits at this bank','Job','Number of people being liable to provide maintenance for','Telephone','foreign worker']
   

for i in credit_data['Age in years']:
    if i>=65:
        i = '65 on up'
    elif i>=55:
        i = '55-64'
    elif i>=45:
        i = '45-54'
    elif i>=35:
        i = '35-44'
    elif i>=25:
        i = '25-34'
    else:
        i = '24 or younger'
        #print(i)

# print credit_data['Duration in month'].max()
# print credit_data['Duration in month'].min()
for i in credit_data['Duration in month']:
    if i>=65:
        i = '65 on up'
    elif i>=55:
        i = '55-64'
    elif i>=45:
        i = '45-54'
    elif i>=35:
        i = '35-44'
    elif i>=25:
        i = '25-34'
    elif i>=15:
        i = '15-24'
    elif i>5:
        i='6-14'
    else:
        i='5 or smaller'
        #print(i)
    # print credit_data['Credit amount'].max()
    # print credit_data['Credit amount'].min()
for i in credit_data['Credit amount']:
    if i >= 0.9 * credit_data['Credit amount'].max():
        i = (str(0.9 * credit_data['Credit amount'].max())) +" - "+str(credit_data['Credit amount'].max())
    elif i >= 0.8 * credit_data['Credit amount'].max():
        i = str(0.8 * credit_data['Credit amount'].max()) + " - " + str(0.9 * credit_data['Credit amount'].max())
    elif i >= 0.7 * credit_data['Credit amount'].max():
        i = str(0.7 * credit_data['Credit amount'].max()) + " - " + str(0.8 * credit_data['Credit amount'].max())
    elif i >= 0.6 * credit_data['Credit amount'].max():
        i = str(0.6 * credit_data['Credit amount'].max()) + " - " + str(0.7 * credit_data['Credit amount'].max())
    elif i >= 0.5 * credit_data['Credit amount'].max():
        i = str(0.5 * credit_data['Credit amount'].max()) + " - " + str(0.6 * credit_data['Credit amount'].max())
    elif i >= 0.4 * credit_data['Credit amount'].max():
        i = str(0.4 * credit_data['Credit amount'].max()) + " - " + str(0.5 * credit_data['Credit amount'].max())
    elif i >= 0.3 * credit_data['Credit amount'].max():
        i = str(0.3 * credit_data['Credit amount'].max()) + " - " + str(0.4 * credit_data['Credit amount'].max())
    elif i >= 0.2 * credit_data['Credit amount'].max():
        i = str(0.2 * credit_data['Credit amount'].max()) + " - " + str(0.3 * credit_data['Credit amount'].max())
    elif i >= 0.1 * credit_data['Credit amount'].max():
        i = str(0.1 * credit_data['Credit amount'].max()) + " - " + str(0.2 * credit_data['Credit amount'].max())
    else:
        i = str(0.0 * credit_data['Credit amount'].max()) + " - " + str(0.1 * credit_data['Credit amount'].max())
    print(i)
    # print credit_data['Installment rate in percentage of disposable income'].max()
    # print credit_data['Installment rate in percentage of disposable income'].min()
for i in credit_data['Installment rate in percentage of disposable income']:
    if i == 4:
        i = '4'
    elif i == 3:
        i = '3'
    elif i == 2:
        i = '2'
    else:
        i = '1'
    #print(i)
# print credit_data['Present residence since'].max()
# print credit_data['Present residence since'].min()
for i in credit_data['Present residence since']:
    if i == 4:
        i = '4'
    elif i == 3:
        i = '3'
    elif i == 2:
        i = '2'
    else:
        i = '1'
    #print(i)
# print credit_data['Number of existing credits at this bank'].max()
# print credit_data['Number of existing credits at this bank'].min()
for i in credit_data['Number of existing credits at this bank']:
    if i == 4:
        i = '4'
    elif i == 3:
        i = '3'
    elif i == 2:
        i = '2'
    else:
        i = '1'
    #print(i)
for i in credit_data['Number of people being liable to provide maintenance for']:
    if i==2:
        i='2'
    elif i==1:
        i='1'
for i in credit_data['Creditability']:
    if i==2:
        i='2'
    elif i==1:
        i='1'    
    #print(i)
#my_tree = DTree() 
#my_tree.fit(train_data,train_data[attributes_to_use],train_data['Creditability'])
#my_tree.print_tree()
print credit_data("Credit Amount")
predictions = my_tree.predict(test_data[attributes_to_use])
print(accuracy(test_data['Creditability'],predictions))
#print(subset1('Job'))

#print(subset2(train_data['Job']))
# Out:
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 3684.8 - 5527.2
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 5527.2 - 7369.6
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 12896.8 - 14739.2
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 9212.0 - 11054.4
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 14739.2 - 16581.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 11054.4 - 12896.8
# 5527.2 - 7369.6
# 5527.2 - 7369.6
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 7369.6 - 9212.0
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 9212.0 - 11054.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 12896.8 - 14739.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 9212.0 - 11054.4
# 3684.8 - 5527.2
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 5527.2 - 7369.6
# 3684.8 - 5527.2
# 7369.6 - 9212.0
# 9212.0 - 11054.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 11054.4 - 12896.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 12896.8 - 14739.2
# 14739.2 - 16581.6
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 12896.8 - 14739.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 12896.8 - 14739.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 14739.2 - 16581.6
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 9212.0 - 11054.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 12896.8 - 14739.2
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 11054.4 - 12896.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 12896.8 - 14739.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 11054.4 - 12896.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 14739.2 - 16581.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 7369.6 - 9212.0
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 7369.6 - 9212.0
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 14739.2 - 16581.6
# 5527.2 - 7369.6
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 9212.0 - 11054.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 16581.6 - 18424
# 1842.4 - 3684.8
# 14739.2 - 16581.6
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 11054.4 - 12896.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 0.0 - 1842.4
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 9212.0 - 11054.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 5527.2 - 7369.6
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 7369.6 - 9212.0
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 7369.6 - 9212.0
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 5527.2 - 7369.6
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 1842.4 - 3684.8
# 0.0 - 1842.4
# 3684.8 - 5527.2
# 0.0 - 1842.4
# 1842.4 - 3684.8
# 3684.8 - 5527.2
# 0.98
